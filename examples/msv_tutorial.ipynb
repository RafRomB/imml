# %%
cd ../src
# Out:
# /home/alberto/Work/incomplete_multiview_clustering/src

# %%
from algorithms.msv import MSV
from utils.utils import RandomMultiviewDataset

# %% [markdown]
# We create a random multi-view dataset with 10 samples.

# %%
rmd = RandomMultiviewDataset()
mvd = rmd.create_mvd(n_samples = 100, n_features = [10, 50, 100], n_clusters = [3, 4, 2])
sample_views = rmd.add_sample_views(mvd = mvd, p = [0.2, 0.3, 0.5])
imvd = rmd.add_missing_views(mvd = mvd, sample_views = sample_views)
for data in imvd:
    display(data.head())
# Out:
#           0         1         2          3         4         5         6
# 1  3.731719 -1.610355  3.427479  -8.870505 -2.913618 -1.298816  4.101272  \
# 2  1.294608 -1.420356  4.015774  -9.778116 -5.576397 -2.614048  4.550485
# 3 -0.257602 -7.771554 -3.141924  -7.612932  9.609044 -7.309815  4.076310
# 5  4.743203 -0.522029  3.149740 -10.487875 -5.422763 -3.243212  3.544846
# 6  8.936832 -2.090753 -2.250770   9.259739  5.703213 -0.045827  4.388626
#
#           7         8          9
# 1 -0.478585 -3.292390 -10.415135
# 2 -0.531958 -2.867314 -11.685519
# 3 -5.805129 -6.646946   2.394356
# 5  1.978565 -3.686952  -9.732813
# 6  8.240468 -5.274890   6.697738
#           0         1         2         3         4          5         6
# 0  -5.481210  3.152898 -6.541785 -1.052315  3.569926  -1.897785 -0.906996  \
# 1  -7.600681  4.250891 -7.266326 -2.012525  4.581274  -3.329374 -1.165360
# 3   4.080203  7.488208 -9.867197 -0.064803 -2.602510  10.699706 -8.061237
# 4  -3.694501 -8.451599 -1.712991  8.277638 -7.680187  -2.627742 -1.425244
# 5  10.400571 -1.882357  2.177602 -2.828650 -6.061578   5.246269 -0.753777
#
#          7         8         9   ...         40        41         42
# 0 -6.401189  5.045050 -4.827783  ...  -7.101910 -4.439202   1.609583  \
# 1 -5.310164  3.498042 -5.384400  ...  -7.343797 -3.316432   1.237810
# 3 -3.168604 -4.377892 -7.197132  ... -10.389187  4.068394   3.313325
# 4 -0.783467 -5.107683  5.299219  ...  -3.047138  5.150722  -6.396813
# 5  3.576069  8.558952  7.034280  ...  -9.963103 -6.292999  11.200017
#
#          43        44        45        46        47        48         49
# 0  5.350561  4.086329 -6.440412  0.731493  5.662754 -5.494628   9.784863
# 1  8.184331  4.359955 -6.638355  0.153280  6.891804 -5.258361  11.643207
# 3  2.359704 -0.595851 -7.671634 -2.165869  5.482026 -0.974795  -4.972357
# 4 -4.769142  1.544525 -1.939082 -5.039488  5.791825  5.763361  -2.305662
# 5  2.184655  9.780399  4.301508  1.074176  5.259261  0.260902   4.518320
#
# [5 rows x 50 columns]
#           0          1         2         3         4         5          6
# 5  -8.148248  -7.238074 -1.908271 -5.094041 -3.729714  1.967802   8.651409  \
# 6  -8.538462  -8.927810 -2.298580 -4.039045 -4.769034  2.055058   9.585545
# 7  -8.163537 -10.802856  1.217409 -4.216918 -3.256867  2.081752  10.418327
# 11  9.672338  -8.070025  3.984675  1.886777  4.102312  8.161200  -6.417399
# 13  9.396336  -8.851199  3.468233  2.172605  3.657896  8.617896  -5.530354
#
#           7         8         9   ...        90        91        92        93
# 5  -0.520914 -9.968318  4.329391  ...  5.388398 -7.125959 -5.047295 -1.299313  \
# 6   0.412898 -9.103673  2.173801  ...  7.124141 -6.162813 -2.767035 -1.883651
# 7  -2.185843 -9.166403  2.415249  ...  5.259745 -5.432812 -4.108469 -2.654530
# 11 -0.196220 -8.348430 -6.401621  ... -7.951399 -4.515273 -6.461632 -2.847596
# 13 -3.030371 -9.175305 -6.569843  ... -5.704613 -6.453262 -7.974316 -2.158746
#
#           94        95        96        97        98         99
# 5   2.656098  5.736845 -5.805286  5.874685  8.951864  -2.668336
# 6   2.784954  4.608081 -4.686038  7.673965  8.796396  -3.188138
# 7   2.102017  5.763769 -5.973020  6.323146  8.527537  -2.929236
# 11  1.019533  7.914037  4.509962  1.245162  8.000285  -9.572936
# 13  0.793533  7.987902  6.234738  1.938412  6.772112 -10.557540
#
# [5 rows x 100 columns]

# %% [markdown]
# Now we will remove some views from the samples.

# %%
estimator = MSV()
estimator.fit(X = imvd)
# Out:
# MSV()

# %%
estimator.pipelines_
# Out:
# [IMCBase(transformers=[FillMissingViews(), SingleView(), StandardScaler()]),
#  IMCBase(transformers=[FillMissingViews(), SingleView(), StandardScaler()]),
#  IMCBase(transformers=[FillMissingViews(), SingleView(), StandardScaler()])]

# %%
estimator.predict(X = imvd)
# Out:
# [array([1, 6, 6, 3, 1, 6, 4, 6, 6, 0, 1, 3, 0, 3, 4, 4, 3, 3, 0, 6, 2, 0,
#         7, 0, 2, 2, 7, 2, 4, 6, 2, 0, 3, 1, 6, 3, 3, 3, 1, 0, 0, 0, 5, 6,
#         2, 2, 3, 3, 4, 6, 3, 1, 4, 1, 2, 5, 7, 2, 1, 1, 5, 1, 4, 1, 3, 2,
#         1, 2, 4, 1, 3, 4, 2, 2, 3, 7, 7, 5, 1, 3, 4, 6, 1, 6, 6, 2, 5, 4,
#         4, 0, 2, 3, 4, 3, 1, 4, 1, 3, 1, 1], dtype=int32),
#  array([3, 2, 2, 0, 3, 2, 4, 2, 2, 7, 3, 0, 2, 0, 4, 4, 0, 0, 7, 2, 1, 2,
#         5, 7, 1, 1, 5, 1, 4, 2, 1, 2, 0, 3, 2, 5, 0, 5, 3, 7, 7, 7, 6, 2,
#         1, 1, 0, 0, 4, 2, 0, 3, 4, 3, 1, 6, 5, 1, 3, 3, 6, 3, 4, 3, 0, 1,
#         3, 1, 4, 3, 5, 4, 1, 1, 0, 5, 5, 6, 3, 0, 4, 2, 3, 2, 2, 1, 6, 4,
#         4, 2, 1, 0, 4, 0, 3, 4, 3, 0, 3, 3], dtype=int32),
#  array([1, 4, 4, 3, 1, 4, 5, 4, 4, 2, 1, 7, 2, 3, 5, 5, 3, 3, 2, 4, 0, 4,
#         7, 2, 0, 0, 7, 0, 5, 4, 0, 2, 3, 1, 4, 7, 3, 7, 1, 2, 2, 2, 6, 4,
#         0, 0, 3, 3, 5, 4, 3, 1, 5, 1, 0, 6, 7, 0, 1, 1, 6, 1, 5, 1, 3, 0,
#         1, 0, 5, 1, 7, 5, 0, 0, 3, 7, 7, 6, 1, 3, 5, 4, 1, 4, 4, 0, 6, 5,
#         5, 4, 0, 3, 5, 7, 1, 5, 1, 7, 1, 1], dtype=int32)]
