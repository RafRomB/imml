# %%
cd ..

# %%
from imvc.datasets import LoadDataset
from imvc.pipelines import NMFCPipeline

# %%
Xs = LoadDataset.load_incomplete_nutrimouse(p = 0.2)
for X in Xs:
    print(X.shape)
    display(X.head())

# %%
estimator = NMFCPipeline(n_clusters = 3)
estimator

# %%
estimator.fit_predict(Xs)
