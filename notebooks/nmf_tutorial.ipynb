# %%
cd ../src
# Out:
# /home/alberto/Work/incomplete_multiview_clustering/src

# %%
from utils import RandomMultiviewDataset
from algorithms import NMFClustering

# %%
rmd = RandomMultiviewDataset()
mvd = rmd.create_mvd(n_samples = 100, n_features = [10, 50, 100], n_clusters = [3, 4, 2])
sample_views = rmd.add_sample_views(mvd = mvd, p = [0.2, 0.3, 0.5])
imvd = rmd.add_missing_views(mvd = mvd, sample_views = sample_views)
for data in imvd:
    print(data.shape)
    display(data.head())
# Out:
# (79, 10)
#           0         1         2         3         4         5         6
# 0  7.275724  3.305179 -1.853128 -7.167743  5.168571  9.317178  4.968581  \
# 1  4.033911  5.834227  6.634790  7.269320 -7.751194 -6.727635  6.366691
# 3  0.825492 -3.027310 -7.702063  7.619762 -3.952315  3.550658 -1.427962
# 4  2.116968  6.065480  5.345190  6.023623 -6.216660 -8.523031  7.040768
# 5  1.499618 -5.703794 -8.317936  8.158375 -4.529183  3.060165 -3.439613
#
#           7         8         9
# 0  9.690671 -8.394220  8.269365
# 1 -8.253250  6.365677 -7.603382
# 3  0.641441 -4.034157 -3.504492
# 4 -6.218988  6.921474 -7.266723
# 5 -3.731269 -0.922099 -3.222935
# (70, 50)
#          0          1         2         3         4         5          6
# 0  7.516489   5.408021 -8.250698 -5.603518  7.907295 -0.420725  -2.344112  \
# 1  7.381825   6.169678 -8.679166 -7.039787  6.028568 -4.155511  -2.759580
# 2  3.219440  -9.905703 -8.184220 -2.766244  1.468984 -1.912702  -0.010273
# 3  3.516339 -10.270170 -6.647416 -1.014379  2.515535 -2.309058   0.611920
# 5 -5.329018  -9.171573 -9.408432  6.020367  9.287929  8.234716  10.146751
#
#          7          8         9   ...        40        41        42        43
# 0 -5.447283  -8.432019 -4.339920  ...  8.756213  4.711787 -4.661583 -6.716808  \
# 1 -4.030265 -10.745784 -3.124795  ...  7.885778  6.782969 -4.904272 -5.932133
# 2 -1.521301  -9.278623  7.489226  ...  8.118129  7.466542 -6.884620 -1.620503
# 3 -0.962599  -7.582287  9.065933  ...  6.296537  8.567335 -6.903805 -1.803811
# 5  1.554634  -0.073111  3.854070  ...  5.943250  5.065590  6.231363  9.150966
#
#          44        45        46        47        48        49
# 0 -3.991358 -5.212380  3.112323 -8.249292 -7.733860  1.096186
# 1 -1.256152 -5.413393  3.573769 -8.688709 -9.445117 -0.623661
# 2 -4.102214  0.324905  8.037785  7.301025 -0.832023 -3.269186
# 3 -5.826729 -0.937900  5.819022  6.443325  1.307470 -1.546546
# 5 -9.178961 -7.863559  1.303760  3.014733  7.944295  6.894388
#
# [5 rows x 50 columns]
# (47, 100)
#           0         1         2         3         4         5         6
# 1  -2.114820  5.746816  4.088070  3.698369 -0.906110 -5.044776  5.884399  \
# 3  -8.634602  5.316274 -6.870292  2.018889 -2.014857  5.292944  4.825523
# 4  -9.344442  4.954489 -3.467053  2.659403 -0.576153  3.237609  5.214617
# 6   0.076782  3.961011  3.860235  3.266674  0.049022 -4.198342  6.034371
# 11  1.224223  6.640422  3.137368  2.210501 -0.815060 -4.076867  4.246315
#
#            7         8         9   ...        90        91        92
# 1    5.119963 -8.108449 -3.758349  ...  6.848517 -5.210028  3.928349  \
# 3    8.959086  0.413330 -8.779892  ... -4.110252  4.205179  4.509230
# 4   10.859673  1.454920 -9.246638  ... -6.013261  0.804884  4.811354
# 6    3.147133 -9.364940 -2.336793  ...  7.681889 -4.056969  6.403913
# 11   5.429976 -9.525709 -4.009109  ...  8.103848 -3.975033  5.513773
#
#           93        94        95        96        97        98         99
# 1  -0.408415 -7.334329  4.050898  1.453994  0.166616 -2.489812  -7.484487
# 3   4.187002  1.367153 -4.845196 -0.342354 -3.105959  6.981818  -8.769435
# 4   4.179389  1.848942 -7.378344 -0.909253 -5.797495  7.078982 -10.445220
# 6   0.852528 -8.439263  6.004635  0.257993  0.604614 -3.262611  -7.414527
# 11  1.771568 -6.907169  4.331408  0.738728  0.708307 -3.138401  -7.334898
#
# [5 rows x 100 columns]

# %%
estimator = NMFClustering()
estimator
# Out:
# NMFClustering()

# %%
estimator.fit_predict(X = imvd)
# Out:
# 0     7
# 1     6
# 2     7
# 3     3
# 4     3
#      ..
# 95    7
# 96    7
# 97    7
# 98    1
# 99    1
# Length: 100, dtype: int64
