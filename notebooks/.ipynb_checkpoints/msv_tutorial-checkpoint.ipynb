# %%
cd ../src
# Out:
# /home/alberto/Work/incomplete_multiview_clustering/src

# %%
from algorithms.msv import MSV
from utils.utils import RandomMultiviewDataset
from utils import MultiSingleP

# %% [markdown]
# We create a random multi-view dataset with 10 samples.

# %%
rmd = RandomMultiviewDataset()
mvd = rmd.create_mvd(n_samples = 100, n_features = [10, 50, 100], n_clusters = [3, 4, 2])
sample_views = rmd.add_sample_views(mvd = mvd, p = [0.2, 0.3, 0.5])
imvd = rmd.add_missing_views(mvd = mvd, sample_views = sample_views)
for data in imvd:
    display(data.head())
# Out:
#           0         1         2         3          4         5         6
# 0  8.100229  1.801392  2.388973 -3.722136   8.631248 -3.224485  9.419921  \
# 1 -2.001712 -5.404877 -5.684302  2.534609  -8.656553  0.634291  0.745119
# 2  9.147318  1.574368  5.427490 -3.779132  10.580950 -7.835036  7.551134
# 3 -1.784601 -6.932714  2.311336  1.275712  -1.132717 -7.816724  5.207350
# 4  9.789246  0.388683  1.381745 -3.965720   9.396086 -5.782434  6.832571
#
#           7         8         9
# 0  9.151503 -7.377932 -5.206574
# 1 -1.924666  0.847376  7.935542
# 2  6.471284 -7.079449 -4.731092
# 3 -8.665939 -9.226906 -7.157100
# 4  7.434292 -8.529894 -4.731195
#          0         1          2         3         4          5         6
# 0  6.760277  4.908054  -0.691853  7.172107 -3.574513  11.027637 -7.647549  \
# 1  4.064691 -1.451333  -4.626633 -2.725884  1.959101   4.759289 -0.543180
# 2  7.860443  2.428964  -0.942701  8.651467 -3.228315  11.042333 -6.561947
# 3  5.362256  4.390867  11.281173  0.981104 -4.888068  -7.206813  5.972501
# 4  6.268237  4.951411   7.986065  0.058486 -4.167720  -9.809175  5.800366
#
#          7         8         9   ...        40        41        42        43
# 0 -7.655598 -2.633877  5.845378  ...  0.565634  1.261270  7.767390 -8.282532  \
# 1  1.646265  0.616669  4.303722  ...  6.194839  9.126001 -6.744961 -1.829572
# 2 -6.926212 -4.044051  7.457187  ... -1.915984  1.245695  7.961433 -7.185362
# 3 -5.776534  0.308840 -7.193745  ... -2.360971 -5.016062 -6.794285 -7.658383
# 4 -5.434389 -0.075237 -6.710654  ... -0.725726 -5.693956 -6.950780 -6.258692
#
#          44         45        46        47         48        49
# 0 -6.340441  -8.979316 -7.951744 -3.799362   7.431933  3.204045
# 1 -2.734592   2.027123 -4.187692 -9.325611  10.614888  6.060070
# 2 -4.608591 -10.777213 -7.780945 -1.413431   4.384965  2.783470
# 3 -0.012857  -1.212951  4.612793 -0.902113  -0.590527  2.588381
# 4  0.460782  -0.273144  6.552420 -1.082315  -0.154448 -0.384804
#
# [5 rows x 50 columns]
#           0         1         2         3         4         5         6
# 1   6.702416  6.511538 -7.483339 -1.652893 -1.602466  0.463162 -6.018274  \
# 2   8.500973  0.037611  6.892476  3.879174  2.964930  2.633077  0.991382
# 5   8.590499  0.545885  7.022893  4.859185  0.709582  1.606354  0.817638
# 11  6.088766  2.326246  5.911719  5.951960  0.902256 -0.509646  2.893300
# 12  6.057290  4.104065 -8.948642 -0.365118 -2.076735  1.100615 -6.888332
#
#           7          8         9   ...        90        91         92
# 1  -4.240553  10.440178  9.725334  ... -8.326833 -7.474154   9.343829  \
# 2   0.165806  -1.878694 -7.330827  ... -9.075478  9.797616 -10.365786
# 5   0.293258  -1.103822 -6.657288  ... -7.373883  7.090573 -10.252052
# 11 -1.469729  -1.245462 -5.155953  ... -9.223338  8.529162  -8.526601
# 12 -2.296249   9.301640  9.318720  ... -6.863228 -6.830762  10.356954
#
#           93        94        95        96        97        98        99
# 1   6.036279  3.627264  6.474695  4.289853 -5.512118 -6.252323 -8.024306
# 2  -3.826645  4.683876 -6.168413  1.607845  5.882084 -8.428558  8.216365
# 5  -3.943592  5.195114 -8.407899 -0.804372  3.262281 -8.914159  6.333468
# 11 -3.274254  4.204512 -6.445560 -0.390581  4.323404 -8.460470  6.117358
# 12  5.682181  5.162817  6.091556  2.170587 -5.577484 -8.204311 -6.411354
#
# [5 rows x 100 columns]

# %% [markdown]
# Now we will remove some views from the samples.

# %%
estimator = MSV()
estimator.fit(X = imvd)
# Out:
# MSV()

# %%
estimator.pipelines_
# Out:
# [IMCBase(transformers=[FillMissingViews(), SingleView(), StandardScaler()]),
#  IMCBase(transformers=[FillMissingViews(), SingleView(view_idx=1),
#                        StandardScaler()]),
#  IMCBase(transformers=[FillMissingViews(), SingleView(view_idx=2),
#                        StandardScaler()])]

# %%
estimator.predict(X = imvd)
# Out:
# [array([6, 3, 2, 4, 7, 2, 5, 1, 1, 2, 0, 5, 4, 1, 4, 4, 4, 4, 0, 0, 0, 2,
#         2, 1, 0, 2, 2, 5, 1, 0, 4, 1, 0, 5, 1, 7, 6, 2, 4, 1, 5, 6, 5, 1,
#         5, 4, 0, 5, 7, 4, 5, 7, 3, 6, 3, 0, 1, 1, 1, 6, 1, 4, 6, 0, 5, 3,
#         1, 3, 1, 1, 5, 7, 3, 5, 5, 3, 7, 0, 1, 0, 2, 0, 6, 3, 2, 3, 6, 3,
#         0, 3, 4, 4, 6, 1, 1, 1, 4, 3, 4, 2], dtype=int32),
#  array([0, 2, 0, 7, 4, 0, 6, 1, 1, 0, 7, 2, 3, 1, 3, 3, 3, 3, 7, 7, 5, 0,
#         0, 1, 5, 0, 0, 6, 1, 7, 3, 1, 5, 6, 1, 4, 4, 0, 3, 1, 6, 4, 6, 1,
#         6, 7, 7, 2, 4, 3, 6, 4, 2, 0, 2, 7, 1, 1, 1, 0, 1, 3, 0, 5, 6, 2,
#         1, 2, 1, 1, 6, 4, 2, 2, 6, 2, 4, 7, 1, 7, 0, 5, 0, 2, 0, 2, 0, 2,
#         7, 2, 3, 3, 0, 1, 1, 1, 3, 2, 3, 0], dtype=int32),
#  array([1, 2, 6, 0, 5, 6, 4, 3, 3, 1, 0, 2, 7, 3, 7, 0, 7, 7, 0, 0, 0, 5,
#         1, 3, 0, 1, 6, 4, 3, 0, 7, 3, 0, 4, 3, 5, 5, 5, 7, 3, 4, 5, 4, 3,
#         4, 0, 0, 2, 5, 0, 4, 5, 2, 1, 2, 0, 3, 3, 3, 1, 3, 7, 1, 0, 4, 2,
#         3, 2, 3, 3, 4, 5, 2, 2, 4, 2, 5, 0, 3, 0, 1, 0, 1, 2, 1, 2, 1, 2,
#         0, 2, 7, 7, 1, 3, 3, 3, 7, 2, 7, 1], dtype=int32)]
