# %%
cd ../src
# Out:
# /home/alberto/Work/incomplete_multiview_clustering/src

# %%
from algorithms.concat import Concat
from utils.utils import RandomMultiviewDataset

# %% [markdown]
# We create a random multi-view dataset with 10 samples.

# %%
rmd = RandomMultiviewDataset()
mvd = rmd.create_mvd(n_samples = 100, n_features = [10, 50, 100], n_clusters = [3, 4, 2])
sample_views = rmd.add_sample_views(mvd = mvd, p = [0.2, 0.3, 0.5])
imvd = rmd.add_missing_views(mvd = mvd, sample_views = sample_views)
for data in imvd:
    display(data.head())
# Out:
#            0         1         2         3          4         5         6
# 0  10.375755  4.885392 -2.587211 -2.880727   9.758357 -8.302721  7.977405  \
# 1   8.705693  2.476613 -2.054233 -2.137342  10.084160 -7.407515  7.470449
# 2  10.235787  4.584346 -4.254545 -4.155016  10.198274 -7.123646  9.365151
# 4  -1.085863  3.021166 -5.202936  8.571173   6.700909  9.220595  9.005846
# 5  -1.398732 -5.224639 -1.820498 -6.317433  -5.701956 -2.396710 -8.359897
#
#           7         8         9
# 0 -7.195065  3.835257  7.837834
# 1 -7.192849  5.796205  7.189196
# 2 -8.604565  5.688146  4.298799
# 4  2.832029  1.201398  4.773188
# 5 -7.306943  5.053663  6.132586
#          0         1         2         3         4         5         6
# 1 -1.855601 -7.565756 -9.586698  8.033441  7.791991  9.928294  3.324055  \
# 3 -1.753424 -4.957324 -9.604435  6.419706  9.196074  9.176025  1.632941
# 4  1.626545 -5.819654 -8.593534  5.307632  8.158453  9.882296  2.289110
# 6  5.535231 -3.061358 -4.161330 -5.596503  6.573096  6.545138  6.381808
# 8 -1.731849 -7.235768 -7.263067  8.151026  7.123043  8.591939  1.067257
#
#          7         8         9   ...        40        41        42         43
# 1 -4.301704  9.004460  4.845851  ...  4.814106  4.788752 -2.879872   9.733099  \
# 3 -3.956110  8.872826  4.727559  ...  5.302680  6.963632 -5.313562  10.383560
# 4 -1.917530  8.996710  3.758786  ...  5.564727  6.500848 -4.543632  10.160909
# 6  4.206605  0.450778  4.072892  ... -1.425052  3.041484  5.541391   6.307044
# 8 -4.432229  7.831759  6.281566  ...  2.866978  5.091598 -5.952280  10.092423
#
#          44        45         46        47        48        49
# 1  5.181606 -1.354050  -9.511909  2.302072 -3.289138 -8.375026
# 3  4.784280 -1.274509 -10.050823  0.429103 -6.179649 -7.347985
# 4  4.810159 -0.258715  -9.216953  5.059445 -4.470012 -9.264460
# 6  0.110224  3.514713   0.912574  6.186532  2.908244  4.283312
# 8  4.388300 -1.373159 -10.016068  0.451372 -4.758330 -7.070479
#
# [5 rows x 50 columns]
#          0         1         2         3         4         5         6
# 0  3.010475  5.899468 -7.519813 -7.543040  2.868446 -0.091626  8.161498  \
# 2  5.892377 -5.889608  2.680651 -5.441707 -3.246184 -3.690295 -2.327799
# 7  5.422838 -5.440698  2.252103 -6.036450 -2.183373 -3.015711 -2.417791
# 8  1.823755  1.788547 -7.041073 -9.923629  0.173169  0.790699  9.617280
# 9  4.161959 -5.961996  2.219342 -5.479505 -1.773514 -1.638235 -4.020592
#
#          7         8         9   ...        90        91        92        93
# 0 -4.024080  3.442772 -0.628010  ...  2.138188 -8.602760  2.782209  4.100576  \
# 2 -7.158093  0.051626 -1.853905  ...  4.941514 -7.162294  7.741769 -7.219928
# 7 -6.767974 -0.710531 -4.029864  ...  6.728775 -8.950962  7.252273 -7.173235
# 8 -4.761437  3.354119  0.713943  ...  2.709397 -8.977037  4.914536  2.696696
# 9 -7.186126  0.023075 -2.489368  ...  7.142726 -7.342721  7.482914 -7.589311
#
#          94        95        96        97        98         99
# 0  2.592528  2.894888  6.946462  0.851758 -5.689775  10.484141
# 2 -7.150128 -1.565203  5.899506  2.193735 -3.604367  -4.945627
# 7 -6.962302 -2.439619  4.578850  2.946000 -3.327944  -6.713036
# 8  0.327321  3.061015  3.956000 -1.803116 -5.389725   9.946514
# 9 -8.769635 -0.876254  6.329980  3.360829 -4.427084  -5.100682
#
# [5 rows x 100 columns]

# %% [markdown]
# Now we will remove some views from the samples.

# %%
estimator = Concat()
estimator.fit(X = imvd)
# Out:
# Concat()

# %%
estimator.predict(X = imvd)
# Out:
# array([3, 1, 7, 1, 1, 6, 6, 7, 3, 7, 5, 3, 7, 1, 4, 6, 5, 7, 3, 6, 6, 6,
#        3, 6, 6, 3, 3, 1, 7, 4, 3, 4, 0, 4, 7, 6, 3, 6, 7, 6, 0, 1, 3, 1,
#        2, 2, 5, 5, 6, 3, 1, 6, 0, 0, 6, 3, 6, 3, 0, 7, 0, 3, 3, 6, 2, 6,
#        1, 7, 3, 7, 6, 7, 6, 3, 4, 6, 5, 1, 1, 3, 3, 4, 3, 1, 0, 7, 7, 2,
#        4, 6, 5, 7, 1, 3, 0, 4, 3, 0, 0, 4], dtype=int32)
