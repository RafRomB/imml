# %%
cd ../src
# Out:
# /home/alberto/Work/incomplete_multiview_clustering/src

# %%
from algorithms.concat import Concat
from utils.utils import RandomMultiviewDataset

# %% [markdown]
# We create a random multi-view dataset with 10 samples.

# %%
rmd = RandomMultiviewDataset()
mvd = rmd.create_mvd(n_samples = 100, n_features = [10, 50, 100], n_clusters = [3, 4, 2])
sample_views = rmd.add_sample_views(mvd = mvd, p = [0.2, 0.3, 0.5])
imvd = rmd.add_missing_views(mvd = mvd, sample_views = sample_views)
for data in imvd:
    display(data.head())
# Out:
#           0         1         2         3         4         5         6
# 0 -0.003677 -2.459624 -7.305558 -3.654105 -1.891103  5.330226 -5.473971  \
# 1  6.319122 -6.940306  1.826353  0.335138  6.603784 -2.345644 -3.681086
# 2  6.238111 -6.796659 -1.213070 -2.646383  5.106940 -2.567653 -2.884079
# 3 -0.411136 -3.155333 -8.822194 -5.935009 -2.385929  5.650390 -3.800097
# 4  0.063435 -4.104173 -8.307834 -5.111668 -3.790563  4.639603 -4.644703
#
#           7          8         9
# 0 -7.780398  -7.117381 -5.012492
# 1 -0.103756  10.253238 -3.700339
# 2 -0.761588   7.713498 -2.272434
# 3 -5.456509  -6.358270 -4.975482
# 4 -6.258971  -7.157434 -5.843363
#          0          1         2         3         4         5         6
# 0 -8.994809  -7.699939 -2.204519  4.715445  4.872123 -6.262540 -7.907444  \
# 1 -7.952795  -6.253791 -1.729013  6.582390  4.527964 -7.217365 -6.132901
# 4 -4.215737 -10.744466  8.147005 -3.432893  7.529430 -2.234496 -4.692518
# 6 -8.028395  -8.205145 -3.572964  6.729178  2.779494 -3.774696 -4.661682
# 7 -8.870059  -7.579333 -4.194841  5.932281  2.923636 -5.714901 -9.052338
#
#          7         8         9   ...         40        41        42        43
# 0 -8.921583  0.826254  7.742617  ...   8.420079 -4.392930 -4.940668  0.146616  \
# 1 -7.704475 -0.081123  7.482378  ...   8.224526 -1.473940 -4.271838  1.453510
# 4  0.655222 -0.029651 -4.877692  ... -11.062719  6.714868  2.818934  3.586563
# 6 -7.516437  0.607418  9.096537  ...   6.473799 -4.867936 -3.777558  1.351077
# 7 -7.834383  2.597422  9.148081  ...   8.837481 -3.937492 -5.219045  0.747050
#
#          44        45        46        47        48        49
# 0  5.859363 -2.524039  2.633609  1.864678 -8.792680 -5.158783
# 1  7.237592 -2.037363  3.107555  1.437429 -9.781234 -5.300337
# 4 -0.405821 -8.453815  8.198025 -6.308952  1.599297  1.008698
# 6  6.736422 -0.903817  2.047608  3.390121 -7.515984 -5.154938
# 7  6.507471 -2.125546  2.757880  2.920619 -7.137680 -4.941445
#
# [5 rows x 50 columns]
#          0         1         2         3         4         5         6
# 1 -5.690795  3.619042 -9.284567 -4.757912 -4.893197 -0.199823  7.792806  \
# 3 -4.836918  1.373386 -9.405847 -6.079658 -4.064402 -1.065314  7.516031
# 5 -5.301516 -5.942898 -5.370733 -5.339794  5.604908 -3.204183 -1.230497
# 6 -5.112604  3.600822 -7.657830 -5.153977 -4.838148 -2.080267  6.831668
# 7 -4.705734  2.586414 -7.862034 -4.600161 -4.755514  0.058192  9.525597
#
#          7          8         9   ...        90        91         92
# 1  3.016805   4.850792 -3.366034  ...  6.012590 -0.349400  11.023858  \
# 3  5.264867   3.276806 -3.127352  ...  9.528400  2.023078  10.761277
# 5 -9.931983  10.451606 -3.941735  ...  1.162236 -4.366462  -0.227364
# 6  6.163992   3.405601 -4.124090  ...  7.098734 -1.418868   9.054647
# 7  4.376121   3.561492 -3.728805  ...  9.899391  1.404546  10.088939
#
#          93         94         95        96        97        98        99
# 1 -1.049237   9.990372  -7.846695  9.645260 -5.218830  0.325739  5.096810
# 3 -2.469678   9.714416  -8.562252  9.829345 -6.019272  0.261161  3.846621
# 5 -0.664448   7.530360 -11.045765 -6.468142  2.845240  0.177467  4.004638
# 6 -1.364944   9.222143  -8.172213  9.830694 -4.823272  1.223872  5.843683
# 7 -1.488926  10.660505  -7.860033  8.317461 -6.801176  0.763884  4.763615
#
# [5 rows x 100 columns]

# %% [markdown]
# Now we will remove some views from the samples.

# %%
estimator = Concat()
estimator.fit(X = imvd)
# Out:
# /home/alberto/anaconda3/envs/imc/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Pipeline(steps=[('fillmissingviews', FillMissingViews()),
#                 ('functiontransformer',
#                  FunctionTransformer(func=<function ConcatenateViews.__new__.<locals>.<lambda> at 0x7f1f9ab76710>)),
#                 ('normalizer', Normalizer()), ('kmeans', KMeans())])

# %%
estimator.predict(X = imvd)
# Out:
# array([0, 3, 1, 3, 6, 2, 3, 0, 0, 6, 7, 4, 5, 1, 4, 2, 1, 2, 2, 0, 4, 3,
#        1, 3, 2, 3, 0, 4, 2, 0, 5, 3, 4, 6, 6, 1, 1, 2, 1, 0, 5, 6, 0, 1,
#        2, 2, 7, 5, 0, 3, 1, 6, 3, 2, 3, 0, 1, 0, 1, 1, 5, 1, 3, 3, 2, 7,
#        3, 2, 6, 0, 1, 3, 3, 5, 3, 2, 6, 0, 6, 7, 5, 6, 0, 5, 2, 6, 3, 6,
#        7, 5, 5, 2, 2, 5, 7, 3, 4, 1, 1, 3], dtype=int32)
